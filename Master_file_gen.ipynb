# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_sample = pd.read_csv('/content/drive/MyDrive/Master_file_MSK-metTropism/data_clinical_sample.txt', sep = '\t', skiprows= 4, header= 0)
data_patient = pd.read_csv('/content/drive/MyDrive/Master_file_MSK-metTropism/data_clinical_patient.txt', sep = '\t', skiprows= 4, header= 0)
data_mutation = pd.read_csv('/content/drive/MyDrive/Master_file_MSK-metTropism/data_mutations.txt', sep = '\t', header= 0)
#data_treatment = pd.read_csv('/content/drive/MyDrive/Dr. V/Big data MSK-CHORD/data_timeline_treatment.txt', sep = '\t',header= 0)
# Out:
# <ipython-input-28-ed2e8980c0d2>:3: DtypeWarning: Columns (44,48,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_mutation = pd.read_csv('/content/drive/MyDrive/Master_file_MSK-metTropism/data_mutations.txt', sep = '\t', header= 0)

# %%
data_mutation = data_mutation.rename(columns={'Tumor_Sample_Barcode': 'SAMPLE_ID'})
#data_treatment.columns
data_mutation.columns
# Out:
# Index(['Hugo_Symbol', 'Entrez_Gene_Id', 'Center', 'NCBI_Build', 'Chromosome',
#        'Start_Position', 'End_Position', 'Strand', 'Consequence',
#        'Variant_Classification',
#        ...
#        'VARIANT_CLASS', 'all_effects', 'amino_acid_change', 'cDNA_Change',
#        'cDNA_position', 'cdna_change', 'comments', 'n_depth', 't_depth',
#        'transcript'],
#       dtype='object', length=122)

# %%
merged_df = data_sample.merge(data_patient, on='PATIENT_ID', how='outer')

# %%
merged_df2 = merged_df.merge(data_mutation, on='SAMPLE_ID', how='outer')
              #\.merge(data_mutation, on='SAMPLE_ID', how='outer')
              #\ .merge(data_treatment, on='PATIENT_ID', how='outer')

# %%
merged_df2.head(5)
# Out:
#            SAMPLE_ID PATIENT_ID ORGAN_SYSTEM ONCOTREE_CODE  \
# 0  P-0000004-T01-IM3  P-0000004       Breast           IDC
# 1  P-0000004-T01-IM3  P-0000004       Breast           IDC
# 2  P-0000004-T01-IM3  P-0000004       Breast           IDC
# 3  P-0000004-T01-IM3  P-0000004       Breast           IDC
# 4  P-0000015-T01-IM3  P-0000015       Breast           IDC
#
#                   SUBTYPE SUBTYPE_ABBREVIATION SAMPLE_TYPE PRIMARY_SITE  \
# 0  Breast Ductal HR+HER2-         IDC HR+HER2-     Primary       Breast
# 1  Breast Ductal HR+HER2-         IDC HR+HER2-     Primary       Breast
# 2  Breast Ductal HR+HER2-         IDC HR+HER2-     Primary       Breast
# 3  Breast Ductal HR+HER2-         IDC HR+HER2-     Primary       Breast
# 4  Breast Ductal HR+HER2-         IDC HR+HER2-  Metastasis       Breast
#
#   METASTATIC_SITE GENE_PANEL  ...  VARIANT_CLASS  all_effects  \
# 0             NaN  IMPACT341  ...            NaN          NaN
# ...

# %%
merged_df2.to_csv('/content/drive/MyDrive/Master_file_MSK-metTropism/Master_file_MSK-metTropism.csv', index=False)

# %%
unique_ids = merged_df2['PATIENT_ID'].unique()
print(len(unique_ids))
# Out:
# 25775
